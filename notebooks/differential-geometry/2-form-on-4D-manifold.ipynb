# %%
M = Manifold(4, 'M')
c_txyz.<t,x,y,z> = M.chart()

# %%
a = M.diff_form(2)
a[0,1] = 2
a[1,2] = 3

# %%
b = M.diff_form(2)
b[0,1], b[0,2], b[0,3] = (1, 2, 3)

# %%
s = a + b; s
# Out:
# 2-form on the 4-dimensional differentiable manifold M

# %%
a[:], b[:], s[:]
# Out:
# (
# [ 0  2  0  0]  [ 0  1  2  3]  [ 0  3  2  3]
# [-2  0  3  0]  [-1  0  0  0]  [-3  0  3  0]
# [ 0 -3  0  0]  [-2  0  0  0]  [-2 -3  0  0]
# [ 0  0  0  0], [-3  0  0  0], [-3  0  0  0]
# )

# %% [markdown]
# 可以看到 form 剛好是矩陣時呈現的形式是 [Antisymmetric Matrix](https://mathworld.wolfram.com/AntisymmetricMatrix.html)
