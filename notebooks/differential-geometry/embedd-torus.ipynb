# %%
T.<theta, phi> = manifolds.Torus(3, 1); T
# Out:
# 2-dimensional Riemannian submanifold T embedded in the Euclidean space E^3

# %%
T.atlas()
# Out:
# [Chart (T, (theta, phi))]

# %%
T.embedding().display()
# Out:
# T → E^3
#    (theta, phi) ↦ (X, Y, Z) = ((cos(theta) + 3)*cos(phi), (cos(theta) + 3)*sin(phi), sin(theta))

# %%
T.metric().display()
# Out:
# gamma = dtheta⊗dtheta + (cos(theta)^2 + 6*cos(theta) + 9) dphi⊗dphi
