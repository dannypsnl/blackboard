# %%
M = Manifold(2, 'S^2', start_index=1)

# %%
c_spher.<θ,ψ> = M.chart(r'θ:(0,pi):\theta ψ:(0,2*pi):\phi')

# %%
g = M.metric('g')
g[1,1], g[2,2] = 1, sin(θ)^2
g.display() # standard metric on S^2
# Out:
# g = dθ⊗dθ + sin(θ)^2 dψ⊗dψ

# %%
nab = g.connection(); nab
# Out:
# Levi-Civita connection nabla_g associated with the Riemannian metric g on the 2-dimensional differentiable manifold S^2

# %%
ric = nab.ricci(); ric
# Out:
# Field of symmetric bilinear forms Ric(g) on the 2-dimensional differentiable manifold S^2

# %%
ric.display()
# Out:
# Ric(g) = dθ⊗dθ + sin(θ)^2 dψ⊗dψ
