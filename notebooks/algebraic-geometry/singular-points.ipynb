# %%
x, y = AffineSpace(2, QQ, 'xy').gens()

# %%
C1 = Curve((x + y - 1) * (x - y -1))
plot(C1)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
C2 = Curve((2*x + 3*y - 4)^2)
plot(C2)
# Out:
# Graphics object consisting of 1 graphics primitive
